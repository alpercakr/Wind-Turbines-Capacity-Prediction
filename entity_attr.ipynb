# %%
import pandas as pd
import numpy as np

# %%
df_info=pd.read_csv('data file/EntityandAttribute_DataDictionary.csv')
df_info.info()
df_info.head(25)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
# field          25 non-null object
# category       25 non-null object
# description    25 non-null object
# non-missing    25 non-null int64
# Min            15 non-null float64
# Median         15 non-null float64
# Max            15 non-null float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.5+ KB
#          field                       category  \
# 0      case_id                             id
# 1      faa_ors                             id
# 2      faa_asn                             id
# 3   usgs_pr_id                             id
# 4       eia_id                             id
# 5      t_state                       location
# 6     t_county                       location
# 7       t_fips                       location
# 8       p_name         project characteristic
# 9       p_year         project characteristic
# ...
